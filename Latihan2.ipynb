# %% [markdown]
# <a href="https://colab.research.google.com/github/RazorChief/StrukturDataD-Pertemuan1/blob/main/Latihan2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. List Kosongan

# %%
list = []

# %% [markdown]
# 2. Input angka dari User

# %%
for i in range(10):
    angka = int(input("Masukkan angka: "))
    list.append(angka)
# Out:
# Masukkan angka: 23
# Masukkan angka: 42
# Masukkan angka: 54
# Masukkan angka: 86
# Masukkan angka: 45
# Masukkan angka: 9
# Masukkan angka: 12
# Masukkan angka: 89
# Masukkan angka: 65
# Masukkan angka: 34

# %% [markdown]
# 3. Hasil output User

# %%
print("List:", list)
print("Nilai maksimum:", max(list))
print("Nilai minimum:", min(list))
print("Rata-rata:", sum(list)/len(list))
# Out:
# List: [23, 42, 54, 86, 45, 9, 12, 89, 65, 34]
# Nilai maksimum: 89
# Nilai minimum: 9
# Rata-rata: 45.9

# %% [markdown]
# 4. Hasil grafik batangan berdasarkan inputan user

# %%
import matplotlib.pyplot as plt
plt.bar(range(len(list)), list)
plt.title("Grafik Array")
plt.xlabel("Indeks")
plt.ylabel("Nilai")
plt.show()
